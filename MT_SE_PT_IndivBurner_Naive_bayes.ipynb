# %%
##Run all the scripts

# %run MT_SE_PT_Preprocess.py
# %run MT_SE_PT_Visusalisation.py

# %%
# %run MT_SE_PT_Funtions.py
# %run MT_SE_PT_Heatmap.py
# %run MT_SE_PT_Tuner.py

# %%
####Preprocess the data
##Train
dataTV = preprocess_indivburn_TV(Gazli20210618Balanced)
##Test 
dataTV2 = preprocess_indivburn_TV(Gazli20210618Unbalanced)
# Out:
# No na values

# %%
##Initialize the model
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
###Training on Best evaluated burner and testing on new data dataTV2
###Train on more switching dataset and train on less switching dataset
bestburner = highestpredburner(dataTV,gnb)
evalmodeltest(dataTV,bestburner,gnb,dataTV2)
# Out:
# The Burner which gives the highest accuracy after testing on all other burners are:  3
# The Burner which gives the lowest accuracy after testing on all other burners are: 6
#
# The score using LogisticRegression after training on burner 3 and testing on burner1 is 99.74299 %
# The score using LogisticRegression after training on burner 3 and testing on burner2 is 99.70519 %
# The score using LogisticRegression after training on burner 3 and testing on burner3 is 99.72787 %
# The score using LogisticRegression after training on burner 3 and testing on burner4 is 99.7959 %
# The score using LogisticRegression after training on burner 3 and testing on burner5 is 99.73543 %
# The score using LogisticRegression after training on burner 3 and testing on burner6 is 99.72787 %
# The score using LogisticRegression after training on burner 3 and testing on burner7 is 99.58425 %
# The score using LogisticRegression after training on burner 3 and testing on burner8 is 99.74299 %

# %%
plotconfusiongrid(dataTV,gnb)
# Out:
# The total Number of False positives in the list is 95
# The total Number of False negatives in the list is 853
# (95, 853, 948)

# %%
plotconfusiongrid(dataTV2,gnb)
# Out:
# The total Number of False positives in the list is 8
# The total Number of False negatives in the list is 235
# (8, 235, 243)

# %%
###Training on Best evaluated burner and testing on new data dataTV
###Train on less switching dataset and testing on more switching dataset.
bestburner = highestpredburner(dataTV2,gnb)
evalmodeltest(dataTV2,bestburner,gnb,dataTV)
# Out:
# The Burner which gives the highest accuracy after testing on all other burners are:  4
# The Burner which gives the lowest accuracy after testing on all other burners are: 3
#
# The score using LogisticRegression after training on burner 5 and testing on burner1 is 99.47577 %
# The score using LogisticRegression after training on burner 5 and testing on burner2 is 99.43465 %
# The score using LogisticRegression after training on burner 5 and testing on burner3 is 99.04405 %
# The score using LogisticRegression after training on burner 5 and testing on burner4 is 99.31644 %
# The score using LogisticRegression after training on burner 5 and testing on burner5 is 99.46035 %
# The score using LogisticRegression after training on burner 5 and testing on burner6 is 99.47063 %
# The score using LogisticRegression after training on burner 5 and testing on burner7 is 99.45521 %
# The score using LogisticRegression after training on burner 5 and testing on burner8 is 99.47063 %

# %%
plotconfusiongrid(dataTV2,gnb)
# Out:
# The total Number of False positives in the list is 8
# The total Number of False negatives in the list is 235
# (8, 235, 243)

# %%
plotconfusiongrid(dataTV,gnb)
# Out:
# The total Number of False positives in the list is 95
# The total Number of False negatives in the list is 853
# (95, 853, 948)

# %%
### Tuning of NB Parameters
Tuned_NB = nb_tuner(dataTV2,bestburner,gnb)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits

# %%
###Training on Best evaluated burner and testing on new data dataTV2
###Train on more switching dataset and train on less switching dataset
# bestburner = highestpredburner(dataTV,gnb)
evalmodeltest(dataTV,bestburner,Tuned_NB,dataTV2)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# The score using LogisticRegression after training on burner 5 and testing on burner1 is 99.74299 %
# The score using LogisticRegression after training on burner 5 and testing on burner2 is 99.67496 %
# The score using LogisticRegression after training on burner 5 and testing on burner3 is 99.72787 %
# The score using LogisticRegression after training on burner 5 and testing on burner4 is 99.7959 %
# The score using LogisticRegression after training on burner 5 and testing on burner5 is 99.73543 %
# The score using LogisticRegression after training on burner 5 and testing on burner6 is 99.72031 %
# The score using LogisticRegression after training on burner 5 and testing on burner7 is 99.60692 %
# The score using LogisticRegression after training on burner 5 and testing on burner8 is 99.75055 %

# %%
plotconfusiongrid(dataTV,Tuned_NB)
# Out:
# The total Number of False positives in the list is 79
# The total Number of False negatives in the list is 908
# (79, 908, 987)

# %%
plotconfusiongrid(dataTV2,Tuned_NB)
# Out:
# The total Number of False positives in the list is 7
# The total Number of False negatives in the list is 290
# (7, 290, 297)

# %%
###Training on Best evaluated burner and testing on new data dataTV
###Train on less switching dataset and testing on more switching dataset.
# bestburner = highestpredburner(dataTV2,gnb)
evalmodeltest(dataTV2,bestburner,Tuned_NB,dataTV)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# The score using LogisticRegression after training on burner 5 and testing on burner1 is 99.60426 %
# The score using LogisticRegression after training on burner 5 and testing on burner2 is 99.58884 %
# The score using LogisticRegression after training on burner 5 and testing on burner3 is 99.23421 %
# The score using LogisticRegression after training on burner 5 and testing on burner4 is 99.52202 %
# The score using LogisticRegression after training on burner 5 and testing on burner5 is 99.59912 %
# The score using LogisticRegression after training on burner 5 and testing on burner6 is 99.62481 %
# The score using LogisticRegression after training on burner 5 and testing on burner7 is 99.5837 %
# The score using LogisticRegression after training on burner 5 and testing on burner8 is 99.59398 %

# %%
plotconfusiongrid(dataTV2,Tuned_NB)
# Out:
# The total Number of False positives in the list is 111
# The total Number of False negatives in the list is 599
# (111, 599, 710)

# %%
plotconfusiongrid(dataTV,Tuned_NB)
# Out:
# The total Number of False positives in the list is 8
# The total Number of False negatives in the list is 154
# (8, 154, 162)
